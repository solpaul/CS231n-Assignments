# %% [markdown]
# # Image features exercise
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# We have seen that we can achieve reasonable performance on an image classification task by training a linear classifier on the pixels of the input image. In this exercise we will show that we can improve our classification performance by training linear classifiers not on raw pixels but on features that are computed from the raw pixels.
#
# All of your work for this exercise will be done in this notebook.

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Load data
# Similar to previous exercises, we will load CIFAR-10 data from disk.

# %%
from cs231n.features import color_histogram_hsv, hog_feature

def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000):
  # Load the raw CIFAR-10 data
  cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
  X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
  
  # Subsample the data
  mask = range(num_training, num_training + num_validation)
  X_val = X_train[mask]
  y_val = y_train[mask]
  mask = range(num_training)
  X_train = X_train[mask]
  y_train = y_train[mask]
  mask = range(num_test)
  X_test = X_test[mask]
  y_test = y_test[mask]

  return X_train, y_train, X_val, y_val, X_test, y_test

X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()

# %% [markdown]
# ## Extract Features
# For each image we will compute a Histogram of Oriented
# Gradients (HOG) as well as a color histogram using the hue channel in HSV
# color space. We form our final feature vector for each image by concatenating
# the HOG and color histogram feature vectors.
#
# Roughly speaking, HOG should capture the texture of the image while ignoring
# color information, and the color histogram represents the color of the input
# image while ignoring texture. As a result, we expect that using both together
# ought to work better than using either alone. Verifying this assumption would
# be a good thing to try for the bonus section.
#
# The `hog_feature` and `color_histogram_hsv` functions both operate on a single
# image and return a feature vector for that image. The extract_features
# function takes a set of images and a list of feature functions and evaluates
# each feature function on each image, storing the results in a matrix where
# each column is the concatenation of all feature vectors for a single image.

# %%
from cs231n.features import *

num_color_bins = 10 # Number of bins in the color histogram
feature_fns = [hog_feature, lambda img: color_histogram_hsv(img, nbin=num_color_bins)]
X_train_feats = extract_features(X_train, feature_fns, verbose=True)
X_val_feats = extract_features(X_val, feature_fns)
X_test_feats = extract_features(X_test, feature_fns)

# Preprocessing: Subtract the mean feature
mean_feat = np.mean(X_train_feats, axis=0, keepdims=True)
X_train_feats -= mean_feat
X_val_feats -= mean_feat
X_test_feats -= mean_feat

# Preprocessing: Divide by standard deviation. This ensures that each feature
# has roughly the same scale.
std_feat = np.std(X_train_feats, axis=0, keepdims=True)
X_train_feats /= std_feat
X_val_feats /= std_feat
X_test_feats /= std_feat

# Preprocessing: Add a bias dimension
X_train_feats = np.hstack([X_train_feats, np.ones((X_train_feats.shape[0], 1))])
X_val_feats = np.hstack([X_val_feats, np.ones((X_val_feats.shape[0], 1))])
X_test_feats = np.hstack([X_test_feats, np.ones((X_test_feats.shape[0], 1))])
# Out:
# Done extracting features for 1000 / 49000 images
# Done extracting features for 2000 / 49000 images
# Done extracting features for 3000 / 49000 images
# Done extracting features for 4000 / 49000 images
# Done extracting features for 5000 / 49000 images
# Done extracting features for 6000 / 49000 images
# Done extracting features for 7000 / 49000 images
# Done extracting features for 8000 / 49000 images
# Done extracting features for 9000 / 49000 images
# Done extracting features for 10000 / 49000 images
# Done extracting features for 11000 / 49000 images
# Done extracting features for 12000 / 49000 images
# Done extracting features for 13000 / 49000 images
# Done extracting features for 14000 / 49000 images
# Done extracting features for 15000 / 49000 images
# Done extracting features for 16000 / 49000 images
# Done extracting features for 17000 / 49000 images
# Done extracting features for 18000 / 49000 images
# Done extracting features for 19000 / 49000 images
# Done extracting features for 20000 / 49000 images
# Done extracting features for 21000 / 49000 images
# Done extracting features for 22000 / 49000 images
# Done extracting features for 23000 / 49000 images
# Done extracting features for 24000 / 49000 images
# Done extracting features for 25000 / 49000 images
# Done extracting features for 26000 / 49000 images
# Done extracting features for 27000 / 49000 images
# Done extracting features for 28000 / 49000 images
# Done extracting features for 29000 / 49000 images
# Done extracting features for 30000 / 49000 images
# Done extracting features for 31000 / 49000 images
# Done extracting features for 32000 / 49000 images
# Done extracting features for 33000 / 49000 images
# Done extracting features for 34000 / 49000 images
# Done extracting features for 35000 / 49000 images
# Done extracting features for 36000 / 49000 images
# Done extracting features for 37000 / 49000 images
# Done extracting features for 38000 / 49000 images
# Done extracting features for 39000 / 49000 images
# Done extracting features for 40000 / 49000 images
# Done extracting features for 41000 / 49000 images
# Done extracting features for 42000 / 49000 images
# Done extracting features for 43000 / 49000 images
# Done extracting features for 44000 / 49000 images
# Done extracting features for 45000 / 49000 images
# Done extracting features for 46000 / 49000 images
# Done extracting features for 47000 / 49000 images
# Done extracting features for 48000 / 49000 images

# %% [markdown]
# ## Train SVM on features
# Using the multiclass SVM code developed earlier in the assignment, train SVMs on top of the features extracted above; this should achieve better results than training SVMs directly on top of raw pixels.

# %%
# Use the validation set to tune the learning rate and regularization strength

from cs231n.classifiers.linear_classifier import LinearSVM

learning_rates = [5e-7, 5e-6]
regularization_strengths = [1e5, 1e6]

results = {}
best_val = -1
best_svm = None


################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained classifer in best_svm. You might also want to play          #
# with different numbers of bins in the color histogram. If you are careful    #
# you should be able to get accuracy of near 0.44 on the validation set.       #
################################################################################
max_count = 100
for count in xrange(max_count):
    lr = np.random.uniform(learning_rates[0], learning_rates[1])
    reg = np.random.uniform(regularization_strengths[0], regularization_strengths[1])

    svm = LinearSVM()
                    
    loss_hist = svm.train(X_train_feats, 
                          y_train, 
                          learning_rate=lr, 
                          reg=reg, 
                          num_iters=1500, 
                          verbose=True)

    y_train_pred = svm.predict(X_train_feats)
    training_accuracy = np.mean(y_train == y_train_pred)
    y_val_pred = svm.predict(X_val_feats)
    validation_accuracy = np.mean(y_val == y_val_pred)

    results[(lr, reg)] = (training_accuracy, validation_accuracy)
        
    if validation_accuracy > best_val:
        best_val = validation_accuracy
        best_svm = svm

################################################################################
#                              END OF YOUR CODE                                #
################################################################################

# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print 'lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy)
    
print 'best validation accuracy achieved during cross-validation: %f' % best_val
# Out:
# lr 5.026698e-07 reg 4.826910e+05 train accuracy: 0.190612 val accuracy: 0.208000
# lr 5.912179e-07 reg 6.130468e+05 train accuracy: 0.182327 val accuracy: 0.186000
# lr 6.614548e-07 reg 7.397929e+05 train accuracy: 0.200571 val accuracy: 0.197000
# lr 6.915371e-07 reg 8.768656e+05 train accuracy: 0.216510 val accuracy: 0.204000
# lr 7.482733e-07 reg 4.959919e+05 train accuracy: 0.244449 val accuracy: 0.238000
# lr 7.484522e-07 reg 4.803157e+05 train accuracy: 0.218612 val accuracy: 0.233000
# lr 7.485143e-07 reg 5.853838e+05 train accuracy: 0.225551 val accuracy: 0.206000
# lr 7.486612e-07 reg 4.605554e+05 train accuracy: 0.227469 val accuracy: 0.213000
# lr 8.535673e-07 reg 5.511439e+05 train accuracy: 0.238388 val accuracy: 0.215000
# lr 8.601126e-07 reg 2.490612e+05 train accuracy: 0.230347 val accuracy: 0.245000
# lr 8.789407e-07 reg 5.734547e+05 train accuracy: 0.230245 val accuracy: 0.240000
# lr 9.205710e-07 reg 8.194263e+05 train accuracy: 0.238490 val accuracy: 0.223000
# lr 1.009327e-06 reg 7.013772e+05 train accuracy: 0.250469 val accuracy: 0.251000
# lr 1.033004e-06 reg 2.484782e+05 train accuracy: 0.274980 val accuracy: 0.257000
# lr 1.037779e-06 reg 3.212079e+05 train accuracy: 0.247061 val accuracy: 0.230000
# lr 1.039250e-06 reg 6.207985e+05 train accuracy: 0.258306 val accuracy: 0.256000
# lr 1.102081e-06 reg 5.227938e+05 train accuracy: 0.268163 val accuracy: 0.251000
# lr 1.183010e-06 reg 3.708133e+05 train accuracy: 0.291041 val accuracy: 0.280000
# lr 1.209402e-06 reg 1.133306e+05 train accuracy: 0.292265 val accuracy: 0.306000
# lr 1.329015e-06 reg 2.101407e+05 train accuracy: 0.276816 val accuracy: 0.274000
# lr 1.362764e-06 reg 7.723533e+05 train accuracy: 0.290898 val accuracy: 0.308000
# lr 1.369967e-06 reg 1.521105e+05 train accuracy: 0.275122 val accuracy: 0.263000
# lr 1.374407e-06 reg 5.703921e+05 train accuracy: 0.295041 val accuracy: 0.316000
# lr 1.473657e-06 reg 2.360925e+05 train accuracy: 0.284143 val accuracy: 0.284000
# lr 1.550854e-06 reg 9.590427e+05 train accuracy: 0.295837 val accuracy: 0.290000
# lr 1.651683e-06 reg 8.503777e+05 train accuracy: 0.294306 val accuracy: 0.300000
# lr 1.778847e-06 reg 8.042659e+05 train accuracy: 0.314041 val accuracy: 0.295000
# lr 1.846987e-06 reg 4.858141e+05 train accuracy: 0.314429 val accuracy: 0.296000
# lr 1.868592e-06 reg 9.565771e+05 train accuracy: 0.322551 val accuracy: 0.317000
# lr 1.895887e-06 reg 2.896035e+05 train accuracy: 0.317980 val accuracy: 0.302000
# lr 1.969684e-06 reg 8.795353e+05 train accuracy: 0.334367 val accuracy: 0.307000
# lr 1.997532e-06 reg 9.223976e+05 train accuracy: 0.325327 val accuracy: 0.312000
# lr 2.031667e-06 reg 9.270147e+05 train accuracy: 0.320061 val accuracy: 0.320000
# lr 2.054749e-06 reg 9.257194e+05 train accuracy: 0.334000 val accuracy: 0.312000
# lr 2.096401e-06 reg 4.332703e+05 train accuracy: 0.342510 val accuracy: 0.344000
# lr 2.138983e-06 reg 8.131777e+05 train accuracy: 0.336735 val accuracy: 0.324000
# lr 2.259559e-06 reg 4.317734e+05 train accuracy: 0.346020 val accuracy: 0.324000
# lr 2.339035e-06 reg 6.818387e+05 train accuracy: 0.354082 val accuracy: 0.350000
# lr 2.421061e-06 reg 3.511886e+05 train accuracy: 0.343551 val accuracy: 0.318000
# lr 2.445864e-06 reg 5.709534e+05 train accuracy: 0.349000 val accuracy: 0.347000
# lr 2.452298e-06 reg 6.218670e+05 train accuracy: 0.352755 val accuracy: 0.343000
# lr 2.488845e-06 reg 1.175984e+05 train accuracy: 0.360653 val accuracy: 0.337000
# lr 2.490901e-06 reg 8.672869e+05 train accuracy: 0.340612 val accuracy: 0.321000
# lr 2.491548e-06 reg 5.443008e+05 train accuracy: 0.348490 val accuracy: 0.360000
# lr 2.550396e-06 reg 5.861028e+05 train accuracy: 0.344714 val accuracy: 0.334000
# lr 2.672415e-06 reg 4.744597e+05 train accuracy: 0.353122 val accuracy: 0.333000
# lr 2.688279e-06 reg 7.686477e+05 train accuracy: 0.353776 val accuracy: 0.337000
# lr 2.691991e-06 reg 8.913421e+05 train accuracy: 0.357408 val accuracy: 0.344000
# lr 2.712650e-06 reg 5.999052e+05 train accuracy: 0.359796 val accuracy: 0.361000
# lr 2.723331e-06 reg 4.004066e+05 train accuracy: 0.356388 val accuracy: 0.339000
# lr 2.762416e-06 reg 4.586033e+05 train accuracy: 0.364653 val accuracy: 0.395000
# lr 2.779902e-06 reg 3.480234e+05 train accuracy: 0.359776 val accuracy: 0.361000
# lr 2.919367e-06 reg 4.557740e+05 train accuracy: 0.355041 val accuracy: 0.348000
# lr 2.923147e-06 reg 3.375186e+05 train accuracy: 0.369347 val accuracy: 0.343000
# lr 2.934539e-06 reg 3.436526e+05 train accuracy: 0.371653 val accuracy: 0.368000
# lr 2.988085e-06 reg 4.188425e+05 train accuracy: 0.364429 val accuracy: 0.361000
# lr 3.043402e-06 reg 4.974461e+05 train accuracy: 0.368429 val accuracy: 0.362000
# lr 3.052531e-06 reg 1.954075e+05 train accuracy: 0.352204 val accuracy: 0.362000
# lr 3.096775e-06 reg 2.635278e+05 train accuracy: 0.367612 val accuracy: 0.355000
# lr 3.097186e-06 reg 6.364732e+05 train accuracy: 0.369143 val accuracy: 0.371000
# lr 3.114405e-06 reg 6.181537e+05 train accuracy: 0.376082 val accuracy: 0.363000
# lr 3.162679e-06 reg 1.935079e+05 train accuracy: 0.367224 val accuracy: 0.341000
# lr 3.174458e-06 reg 9.529715e+05 train accuracy: 0.359571 val accuracy: 0.375000
# lr 3.184697e-06 reg 8.542007e+05 train accuracy: 0.362878 val accuracy: 0.336000
# lr 3.203028e-06 reg 6.516455e+05 train accuracy: 0.377490 val accuracy: 0.383000
# lr 3.305380e-06 reg 4.768454e+05 train accuracy: 0.389469 val accuracy: 0.392000
# lr 3.390093e-06 reg 8.091510e+05 train accuracy: 0.377388 val accuracy: 0.362000
# lr 3.400104e-06 reg 6.564121e+05 train accuracy: 0.379735 val accuracy: 0.381000
# lr 3.450830e-06 reg 8.480944e+05 train accuracy: 0.379041 val accuracy: 0.391000
# lr 3.601807e-06 reg 9.273377e+05 train accuracy: 0.388980 val accuracy: 0.389000
# lr 3.634812e-06 reg 2.041217e+05 train accuracy: 0.378347 val accuracy: 0.374000
# lr 3.636211e-06 reg 4.121582e+05 train accuracy: 0.389837 val accuracy: 0.390000
# lr 3.656143e-06 reg 7.015616e+05 train accuracy: 0.369918 val accuracy: 0.355000
# lr 3.721278e-06 reg 2.733608e+05 train accuracy: 0.367735 val accuracy: 0.368000
# lr 3.855742e-06 reg 6.544176e+05 train accuracy: 0.370653 val accuracy: 0.360000
# lr 3.868498e-06 reg 9.821179e+05 train accuracy: 0.383551 val accuracy: 0.373000
# lr 3.874095e-06 reg 3.161053e+05 train accuracy: 0.369061 val accuracy: 0.361000
# lr 3.876696e-06 reg 6.841204e+05 train accuracy: 0.380653 val accuracy: 0.386000
# lr 3.903892e-06 reg 7.631717e+05 train accuracy: 0.380633 val accuracy: 0.389000
# lr 3.937906e-06 reg 5.280170e+05 train accuracy: 0.384000 val accuracy: 0.391000
# lr 4.106218e-06 reg 8.124495e+05 train accuracy: 0.366469 val accuracy: 0.362000
# lr 4.131946e-06 reg 9.630166e+05 train accuracy: 0.383959 val accuracy: 0.395000
# lr 4.146718e-06 reg 6.252088e+05 train accuracy: 0.379449 val accuracy: 0.379000
# lr 4.279957e-06 reg 6.262282e+05 train accuracy: 0.393041 val accuracy: 0.401000
# lr 4.299313e-06 reg 9.768023e+05 train accuracy: 0.382143 val accuracy: 0.367000
# lr 4.385439e-06 reg 3.381925e+05 train accuracy: 0.384245 val accuracy: 0.397000
# lr 4.465736e-06 reg 4.673703e+05 train accuracy: 0.389449 val accuracy: 0.384000
# lr 4.479406e-06 reg 6.104733e+05 train accuracy: 0.378163 val accuracy: 0.366000
# lr 4.489833e-06 reg 4.696845e+05 train accuracy: 0.380429 val accuracy: 0.385000
# lr 4.503857e-06 reg 2.098630e+05 train accuracy: 0.395082 val accuracy: 0.397000
# lr 4.557244e-06 reg 1.370780e+05 train accuracy: 0.400571 val accuracy: 0.415000
# lr 4.576784e-06 reg 2.616074e+05 train accuracy: 0.384469 val accuracy: 0.380000
# lr 4.585794e-06 reg 9.937104e+05 train accuracy: 0.397816 val accuracy: 0.393000
# lr 4.650742e-06 reg 6.400673e+05 train accuracy: 0.384673 val accuracy: 0.373000
# lr 4.688873e-06 reg 3.588264e+05 train accuracy: 0.393265 val accuracy: 0.393000
# lr 4.707646e-06 reg 5.216309e+05 train accuracy: 0.394367 val accuracy: 0.388000
# lr 4.719382e-06 reg 6.292694e+05 train accuracy: 0.391306 val accuracy: 0.396000
# lr 4.781391e-06 reg 3.511277e+05 train accuracy: 0.395020 val accuracy: 0.405000
# lr 4.849921e-06 reg 2.120888e+05 train accuracy: 0.392306 val accuracy: 0.379000
# lr 4.985981e-06 reg 7.653982e+05 train accuracy: 0.397184 val accuracy: 0.406000
# best validation accuracy achieved during cross-validation: 0.415000

# %%
# Evaluate your trained SVM on the test set
y_test_pred = best_svm.predict(X_test_feats)
test_accuracy = np.mean(y_test == y_test_pred)
print test_accuracy
# Out:
# 0.394

# %%
# An important way to gain intuition about how an algorithm works is to
# visualize the mistakes that it makes. In this visualization, we show examples
# of images that are misclassified by our current system. The first column
# shows images that our system labeled as "plane" but whose true label is
# something other than "plane".

examples_per_class = 8
classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for cls, cls_name in enumerate(classes):
    idxs = np.where((y_test != cls) & (y_test_pred == cls))[0]
    idxs = np.random.choice(idxs, examples_per_class, replace=False)
    for i, idx in enumerate(idxs):
        plt.subplot(examples_per_class, len(classes), i * len(classes) + cls + 1)
        plt.imshow(X_test[idx].astype('uint8'))
        plt.axis('off')
        if i == 0:
            plt.title(cls_name)
plt.show()

# %% [markdown]
# ### Inline question 1:
# Describe the misclassification results that you see. Do they make sense?
#
# Some make sense. There are often cases where the shapes of the miss-classified objects do resemble the miss-classification; likewise the background colour is sometimes much like the typical background colour of the miss-classification.

# %% [markdown]
# ## Neural Network on image features
# Earlier in this assigment we saw that training a two-layer neural network on raw pixels achieved better classification performance than linear classifiers on raw pixels. In this notebook we have seen that linear classifiers on image features outperform linear classifiers on raw pixels.
#
# For completeness, we should also try training a neural network on image features. This approach should outperform all previous approaches: you should easily be able to achieve over 55% classification accuracy on the test set; our best model achieves about 60% classification accuracy.

# %%
print X_train_feats.shape

# %%
################################################################################
# TODO: Train a two-layer neural network on image features. You may want to    #
# cross-validate various parameters as in previous sections. Store your best   #
# model in the best_net variable.                                              #
################################################################################
from cs231n.classifiers.neural_net import TwoLayerNet

results = {}
best_val = -1
input_size = 32 * 32 * 3
num_classes = 10
learning_rates = [1e-1, 5]
regularization_strengths = [1e-3, 1e-2]

max_count = 20

for count in xrange(max_count):
    lr = np.random.uniform(learning_rates[0], learning_rates[1])
    reg = np.random.uniform(regularization_strengths[0], regularization_strengths[1])
    
    input_dim = X_train_feats.shape[1]
    hidden_dim = 500

    net = TwoLayerNet(input_dim, hidden_dim, num_classes)

        # Train the network
    stats = net.train(X_train_feats, y_train, X_val_feats, y_val,
            num_iters=2500, batch_size=200,
            learning_rate=lr, learning_rate_decay=0.95,
            reg=reg, verbose=True)

    # Predict on the validation set
    train_acc = (net.predict(X_train_feats) == y_train).mean()
    val_acc = (net.predict(X_val_feats) == y_val).mean()
    results[(lr, reg)] = (train_acc, val_acc)
    
    if val_acc > best_val:
        best_val = val_acc
        best_net = net

# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print 'lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy)
    
print 'best validation accuracy achieved during cross-validation: %f' % best_val
################################################################################
#                              END OF YOUR CODE                                #
################################################################################
# Out:
# iteration 0 / 2500: loss 2.302587
# iteration 100 / 2500: loss 1.998392
# iteration 200 / 2500: loss 1.827997
# iteration 300 / 2500: loss 1.908563
# iteration 400 / 2500: loss 1.875680
# iteration 500 / 2500: loss 1.726708
# iteration 600 / 2500: loss 1.828157
# iteration 700 / 2500: loss 1.654047
# iteration 800 / 2500: loss 1.687517
# iteration 900 / 2500: loss 1.706633
# iteration 1000 / 2500: loss 1.644915
# iteration 1100 / 2500: loss 1.641980
# iteration 1200 / 2500: loss 1.841229
# iteration 1300 / 2500: loss 1.721451
# iteration 1400 / 2500: loss 1.818815
# iteration 1500 / 2500: loss 1.960498
# iteration 1600 / 2500: loss 1.582986
# iteration 1700 / 2500: loss 1.738213
# iteration 1800 / 2500: loss 1.629516
# iteration 1900 / 2500: loss 1.801910
# iteration 2000 / 2500: loss 1.460402
# iteration 2100 / 2500: loss 1.425003
# iteration 2200 / 2500: loss 1.638913
# iteration 2300 / 2500: loss 1.628587
# iteration 2400 / 2500: loss 1.515511
# iteration 0 / 2500: loss 2.302587
# iteration 100 / 2500: loss 1.682451
# iteration 200 / 2500: loss 1.748645
# iteration 300 / 2500: loss 1.734891
# iteration 400 / 2500: loss 1.770899
# iteration 500 / 2500: loss 1.732151
# iteration 600 / 2500: loss 2.048240
# iteration 700 / 2500: loss 1.750780
# iteration 800 / 2500: loss 1.571311
# iteration 900 / 2500: loss 1.688721
# iteration 1000 / 2500: loss 1.723928
# iteration 1100 / 2500: loss 1.731730
# iteration 1200 / 2500: loss 1.644975
# iteration 1300 / 2500: loss 1.598833
# iteration 1400 / 2500: loss 1.607962
# iteration 1500 / 2500: loss 1.553810
# iteration 1600 / 2500: loss 1.511643
# iteration 1700 / 2500: loss 1.714411
# iteration 1800 / 2500: loss 1.504514
# iteration 1900 / 2500: loss 1.574745
# iteration 2000 / 2500: loss 1.528677
# iteration 2100 / 2500: loss 1.659982
# iteration 2200 / 2500: loss 1.430373
# iteration 2300 / 2500: loss 1.520788
# iteration 2400 / 2500: loss 1.533095
# iteration 0 / 2500: loss 2.302588
# iteration 100 / 2500: loss 1.590802
# iteration 200 / 2500: loss 1.663870
# iteration 300 / 2500: loss 1.753957
# iteration 400 / 2500: loss 1.666225
# iteration 500 / 2500: loss 1.680653
# iteration 600 / 2500: loss 1.764918
# iteration 700 / 2500: loss 1.605293
# iteration 800 / 2500: loss 1.574274
# iteration 900 / 2500: loss 1.550431
# iteration 1000 / 2500: loss 1.598030
# iteration 1100 / 2500: loss 1.570113
# iteration 1200 / 2500: loss 1.693845
# iteration 1300 / 2500: loss 1.620967
# iteration 1400 / 2500: loss 1.633362
# iteration 1500 / 2500: loss 1.469452
# iteration 1600 / 2500: loss 1.689081
# iteration 1700 / 2500: loss 1.572338
# iteration 1800 / 2500: loss 1.567577
# iteration 1900 / 2500: loss 1.578530
# iteration 2000 / 2500: loss 1.684087
# iteration 2100 / 2500: loss 1.520587
# iteration 2200 / 2500: loss 1.595719
# iteration 2300 / 2500: loss 1.471447
# iteration 2400 / 2500: loss 1.661977
# iteration 0 / 2500: loss 2.302588
# iteration 100 / 2500: loss 1.709708
# iteration 200 / 2500: loss 1.497076
# iteration 300 / 2500: loss 1.387468
# iteration 400 / 2500: loss 1.469783
# iteration 500 / 2500: loss 1.348249
# iteration 600 / 2500: loss 1.358582
# iteration 700 / 2500: loss 1.518310
# iteration 800 / 2500: loss 1.475264
# iteration 900 / 2500: loss 1.496058
# iteration 1000 / 2500: loss 1.374945
# iteration 1100 / 2500: loss 1.365274
# iteration 1200 / 2500: loss 1.414812
# iteration 1300 / 2500: loss 1.493806
# iteration 1400 / 2500: loss 1.491982
# iteration 1500 / 2500: loss 1.337696
# iteration 1600 / 2500: loss 1.404776
# iteration 1700 / 2500: loss 1.351173
# iteration 1800 / 2500: loss 1.399381
# iteration 1900 / 2500: loss 1.432732
# iteration 2000 / 2500: loss 1.308329
# iteration 2100 / 2500: loss 1.336706
# iteration 2200 / 2500: loss 1.318115
# iteration 2300 / 2500: loss 1.370819
# iteration 2400 / 2500: loss 1.553610
# iteration 0 / 2500: loss 2.302586
# iteration 100 / 2500: loss 2.782106
# iteration 200 / 2500: loss 2.294577
# iteration 300 / 2500: loss 2.056330
# iteration 400 / 2500: loss 2.134067
# iteration 500 / 2500: loss 2.017125
# iteration 600 / 2500: loss 2.054335
# iteration 700 / 2500: loss 1.978687
# iteration 800 / 2500: loss 2.072953
# iteration 900 / 2500: loss 2.002148
# iteration 1000 / 2500: loss 1.736988
# iteration 1100 / 2500: loss 2.027401
# iteration 1200 / 2500: loss 1.846698
# iteration 1300 / 2500: loss 1.849714
# iteration 1400 / 2500: loss 2.149235
# iteration 1500 / 2500: loss 1.913738
# iteration 1600 / 2500: loss 1.651651
# iteration 1700 / 2500: loss 1.727470
# iteration 1800 / 2500: loss 1.751944
# iteration 1900 / 2500: loss 1.601929
# iteration 2000 / 2500: loss 1.816834
# iteration 2100 / 2500: loss 1.698231
# iteration 2200 / 2500: loss 1.734429
# iteration 2300 / 2500: loss 1.664275
# iteration 2400 / 2500: loss 1.827058
# iteration 0 / 2500: loss 2.302587
# iteration 100 / 2500: loss 1.553104
# iteration 200 / 2500: loss 1.538260
# iteration 300 / 2500: loss 1.434906
# iteration 400 / 2500: loss 1.399547
# iteration 500 / 2500: loss 1.408191
# iteration 600 / 2500: loss 1.524843
# iteration 700 / 2500: loss 1.562529
# iteration 800 / 2500: loss 1.260458
# iteration 900 / 2500: loss 1.352885
# iteration 1000 / 2500: loss 1.202515
# iteration 1100 / 2500: loss 1.458274
# iteration 1200 / 2500: loss 1.442441
# iteration 1300 / 2500: loss 1.410289
# iteration 1400 / 2500: loss 1.263320
# iteration 1500 / 2500: loss 1.382164
# iteration 1600 / 2500: loss 1.398568
# iteration 1700 / 2500: loss 1.531358
# iteration 1800 / 2500: loss 1.348354
# iteration 1900 / 2500: loss 1.285161
# iteration 2000 / 2500: loss 1.342308
# iteration 2100 / 2500: loss 1.367400
# iteration 2200 / 2500: loss 1.358294
# iteration 2300 / 2500: loss 1.341167
# iteration 2400 / 2500: loss 1.330117
# iteration 0 / 2500: loss 2.302586
# iteration 100 / 2500: loss 1.679665
# iteration 200 / 2500: loss 1.615109
# iteration 300 / 2500: loss 1.602991
# iteration 400 / 2500: loss 1.728942
# iteration 500 / 2500: loss 1.508290
# iteration 600 / 2500: loss 1.586572
# iteration 700 / 2500: loss 1.590702
# iteration 800 / 2500: loss 1.474448
# iteration 900 / 2500: loss 1.642853
# iteration 1000 / 2500: loss 1.562181
# iteration 1100 / 2500: loss 1.621278
# iteration 1200 / 2500: loss 1.445827
# iteration 1300 / 2500: loss 1.386046
# iteration 1400 / 2500: loss 1.505185
# iteration 1500 / 2500: loss 1.414889
# iteration 1600 / 2500: loss 1.522613
# iteration 1700 / 2500: loss 1.515399
# iteration 1800 / 2500: loss 1.527569
# iteration 1900 / 2500: loss 1.530851
# iteration 2000 / 2500: loss 1.359790
# iteration 2100 / 2500: loss 1.453112
# iteration 2200 / 2500: loss 1.465788
# iteration 2300 / 2500: loss 1.456106
# iteration 2400 / 2500: loss 1.321122
# iteration 0 / 2500: loss 2.302586
# iteration 100 / 2500: loss 1.897961
# iteration 200 / 2500: loss 1.961842
# iteration 300 / 2500: loss 1.976453
# iteration 400 / 2500: loss 2.111295
# iteration 500 / 2500: loss 1.917692
# iteration 600 / 2500: loss 1.731159
# iteration 700 / 2500: loss 1.873250
# iteration 800 / 2500: loss 1.645962
# iteration 900 / 2500: loss 1.768720
# iteration 1000 / 2500: loss 1.814393
# iteration 1100 / 2500: loss 1.667278
# iteration 1200 / 2500: loss 1.557864
# iteration 1300 / 2500: loss 1.676917
# iteration 1400 / 2500: loss 1.790840
# iteration 1500 / 2500: loss 1.496648
# iteration 1600 / 2500: loss 1.614602
# iteration 1700 / 2500: loss 1.729285
# iteration 1800 / 2500: loss 1.497848
# iteration 1900 / 2500: loss 1.601806
# iteration 2000 / 2500: loss 1.645012
# iteration 2100 / 2500: loss 1.593691
# iteration 2200 / 2500: loss 1.526796
# iteration 2300 / 2500: loss 1.503020
# iteration 2400 / 2500: loss 1.507611
# iteration 0 / 2500: loss 2.302589
# cs231n/classifiers/neural_net.py:96: RuntimeWarning: divide by zero encountered in log
#   correct_log_probs = -np.log(probs[np.arange(N), y])
# cs231n/classifiers/neural_net.py:94: RuntimeWarning: invalid value encountered in divide
#   probs = np.exp(scores) / np.sum(np.exp(scores), axis=1, keepdims=True)
# cs231n/classifiers/neural_net.py:142: RuntimeWarning: invalid value encountered in less_equal
#   dhidden[hidden <= 0] = 0
# iteration 100 / 2500: loss nan
# iteration 200 / 2500: loss nan
# iteration 300 / 2500: loss nan
# iteration 400 / 2500: loss nan
# iteration 500 / 2500: loss nan
# iteration 600 / 2500: loss nan
# iteration 700 / 2500: loss nan
# iteration 800 / 2500: loss nan
# iteration 900 / 2500: loss nan
# iteration 1000 / 2500: loss nan
# iteration 1100 / 2500: loss nan
# iteration 1200 / 2500: loss nan
# iteration 1300 / 2500: loss nan
# iteration 1400 / 2500: loss nan
# iteration 1500 / 2500: loss nan
# iteration 1600 / 2500: loss nan
# iteration 1700 / 2500: loss nan
# iteration 1800 / 2500: loss nan
# iteration 1900 / 2500: loss nan
# iteration 2000 / 2500: loss nan
# iteration 2100 / 2500: loss nan
# iteration 2200 / 2500: loss nan
# iteration 2300 / 2500: loss nan
# iteration 2400 / 2500: loss nan
# iteration 0 / 2500: loss 2.302588
# iteration 100 / 2500: loss nan
# iteration 200 / 2500: loss nan
# iteration 300 / 2500: loss nan
# iteration 400 / 2500: loss nan
# iteration 500 / 2500: loss nan
# iteration 600 / 2500: loss nan
# iteration 700 / 2500: loss nan
# iteration 800 / 2500: loss nan
# iteration 900 / 2500: loss nan
# iteration 1000 / 2500: loss nan
# iteration 1100 / 2500: loss nan
# iteration 1200 / 2500: loss nan
# iteration 1300 / 2500: loss nan
# iteration 1400 / 2500: loss nan
# iteration 1500 / 2500: loss nan
# iteration 1600 / 2500: loss nan
# iteration 1700 / 2500: loss nan
# iteration 1800 / 2500: loss nan
# iteration 1900 / 2500: loss nan
# iteration 2000 / 2500: loss nan
# iteration 2100 / 2500: loss nan
# iteration 2200 / 2500: loss nan
# iteration 2300 / 2500: loss nan
# iteration 2400 / 2500: loss nan
# iteration 0 / 2500: loss 2.302587
# iteration 100 / 2500: loss 2.153081
# iteration 200 / 2500: loss 2.045129
# iteration 300 / 2500: loss 1.921579
# iteration 400 / 2500: loss 1.985475
# iteration 500 / 2500: loss 1.753799
# iteration 600 / 2500: loss 1.926713
# iteration 700 / 2500: loss 1.907597
# iteration 800 / 2500: loss 1.765728
# iteration 900 / 2500: loss 1.852701
# iteration 1000 / 2500: loss 1.731543
# iteration 1100 / 2500: loss 1.640496
# iteration 1200 / 2500: loss 1.677102
# iteration 1300 / 2500: loss 1.826422
# iteration 1400 / 2500: loss 1.723379
# iteration 1500 / 2500: loss 1.746515
# iteration 1600 / 2500: loss 1.724654
# iteration 1700 / 2500: loss 1.589179
# iteration 1800 / 2500: loss 1.653213
# iteration 1900 / 2500: loss 1.790388
# iteration 2000 / 2500: loss 1.849448
# iteration 2100 / 2500: loss 1.695707
# iteration 2200 / 2500: loss 1.876288
# iteration 2300 / 2500: loss 1.667308
# iteration 2400 / 2500: loss 1.885467
# iteration 0 / 2500: loss 2.302589
# iteration 100 / 2500: loss 1.534734
# iteration 200 / 2500: loss 1.474678
# iteration 300 / 2500: loss 1.466871
# iteration 400 / 2500: loss 1.449017
# iteration 500 / 2500: loss 1.391948
# iteration 600 / 2500: loss 1.435303
# iteration 700 / 2500: loss 1.582253
# iteration 800 / 2500: loss 1.563919
# iteration 900 / 2500: loss 1.419197
# iteration 1000 / 2500: loss 1.457854
# iteration 1100 / 2500: loss 1.449424
# iteration 1200 / 2500: loss 1.551444
# iteration 1300 / 2500: loss 1.472941
# iteration 1400 / 2500: loss 1.453912
# iteration 1500 / 2500: loss 1.436025
# iteration 1600 / 2500: loss 1.458398
# iteration 1700 / 2500: loss 1.420948
# iteration 1800 / 2500: loss 1.439352
# iteration 1900 / 2500: loss 1.385379
# iteration 2000 / 2500: loss 1.521861
# iteration 2100 / 2500: loss 1.508920
# iteration 2200 / 2500: loss 1.388281
# iteration 2300 / 2500: loss 1.377970
# iteration 2400 / 2500: loss 1.477598
# iteration 0 / 2500: loss 2.302587
# iteration 100 / 2500: loss 1.399005
# iteration 200 / 2500: loss 1.426502
# iteration 300 / 2500: loss 1.444630
# iteration 400 / 2500: loss 1.380078
# iteration 500 / 2500: loss 1.375855
# iteration 600 / 2500: loss 1.383837
# iteration 700 / 2500: loss 1.392589
# iteration 800 / 2500: loss 1.321022
# iteration 900 / 2500: loss 1.262640
# iteration 1000 / 2500: loss 1.242411
# iteration 1100 / 2500: loss 1.380755
# iteration 1200 / 2500: loss 1.280978
# iteration 1300 / 2500: loss 1.467574
# iteration 1400 / 2500: loss 1.309942
# iteration 1500 / 2500: loss 1.356404
# iteration 1600 / 2500: loss 1.286595
# iteration 1700 / 2500: loss 1.261905
# iteration 1800 / 2500: loss 1.271833
# iteration 1900 / 2500: loss 1.225575
# iteration 2000 / 2500: loss 1.399384
# iteration 2100 / 2500: loss 1.306118
# iteration 2200 / 2500: loss 1.351392
# iteration 2300 / 2500: loss 1.259717
# iteration 2400 / 2500: loss 1.296931
# iteration 0 / 2500: loss 2.302587
# iteration 100 / 2500: loss 1.613522
# iteration 200 / 2500: loss 1.542203
# iteration 300 / 2500: loss 1.626397
# iteration 400 / 2500: loss 1.814160
# iteration 500 / 2500: loss 1.432224
# iteration 600 / 2500: loss 1.401548
# iteration 700 / 2500: loss 1.376949
# iteration 800 / 2500: loss 1.493725
# iteration 900 / 2500: loss 1.272586
# iteration 1000 / 2500: loss 1.514809
# iteration 1100 / 2500: loss 1.477029
# iteration 1200 / 2500: loss 1.282393
# iteration 1300 / 2500: loss 1.374636
# iteration 1400 / 2500: loss 1.482720
# iteration 1500 / 2500: loss 1.462048
# iteration 1600 / 2500: loss 1.409844
# iteration 1700 / 2500: loss 1.539367
# iteration 1800 / 2500: loss 1.367908
# iteration 1900 / 2500: loss 1.476586
# iteration 2000 / 2500: loss 1.328850
# iteration 2100 / 2500: loss 1.292126
# iteration 2200 / 2500: loss 1.242488
# iteration 2300 / 2500: loss 1.370357
# iteration 2400 / 2500: loss 1.320205
# iteration 0 / 2500: loss 2.302588
# iteration 100 / 2500: loss nan
# iteration 200 / 2500: loss nan
# iteration 300 / 2500: loss nan
# iteration 400 / 2500: loss nan
# iteration 500 / 2500: loss nan
# iteration 600 / 2500: loss nan
# iteration 700 / 2500: loss nan
# iteration 800 / 2500: loss nan
# iteration 900 / 2500: loss nan
# iteration 1000 / 2500: loss nan
# iteration 1100 / 2500: loss nan
# iteration 1200 / 2500: loss nan
# iteration 1300 / 2500: loss nan
# iteration 1400 / 2500: loss nan
# iteration 1500 / 2500: loss nan
# iteration 1600 / 2500: loss nan
# iteration 1700 / 2500: loss nan
# iteration 1800 / 2500: loss nan
# iteration 1900 / 2500: loss nan
# iteration 2000 / 2500: loss nan
# iteration 2100 / 2500: loss nan
# iteration 2200 / 2500: loss nan
# iteration 2300 / 2500: loss nan
# iteration 2400 / 2500: loss nan
# iteration 0 / 2500: loss 2.302589
# iteration 100 / 2500: loss nan
# iteration 200 / 2500: loss nan
# iteration 300 / 2500: loss nan
# iteration 400 / 2500: loss nan
# iteration 500 / 2500: loss nan
# iteration 600 / 2500: loss nan
# iteration 700 / 2500: loss nan
# iteration 800 / 2500: loss nan
# iteration 900 / 2500: loss nan
# iteration 1000 / 2500: loss nan
# iteration 1100 / 2500: loss nan
# iteration 1200 / 2500: loss nan
# iteration 1300 / 2500: loss nan
# iteration 1400 / 2500: loss nan
# iteration 1500 / 2500: loss nan
# iteration 1600 / 2500: loss nan
# iteration 1700 / 2500: loss nan
# iteration 1800 / 2500: loss nan
# iteration 1900 / 2500: loss nan
# iteration 2000 / 2500: loss nan
# iteration 2100 / 2500: loss nan
# iteration 2200 / 2500: loss nan
# iteration 2300 / 2500: loss nan
# iteration 2400 / 2500: loss nan
# iteration 0 / 2500: loss 2.302587
# iteration 100 / 2500: loss 1.631317
# iteration 200 / 2500: loss 1.654829
# iteration 300 / 2500: loss 1.671187
# iteration 400 / 2500: loss 1.619569
# iteration 500 / 2500: loss 1.397285
# iteration 600 / 2500: loss 1.533817
# iteration 700 / 2500: loss 1.525187
# iteration 800 / 2500: loss 1.617822
# iteration 900 / 2500: loss 1.631314
# iteration 1000 / 2500: loss 1.364576
# iteration 1100 / 2500: loss 1.645553
# iteration 1200 / 2500: loss 1.527355
# iteration 1300 / 2500: loss 1.573691
# iteration 1400 / 2500: loss 1.559855
# iteration 1500 / 2500: loss 1.579797
# iteration 1600 / 2500: loss 1.542680
# iteration 1700 / 2500: loss 1.504484
# iteration 1800 / 2500: loss 1.299121
# iteration 1900 / 2500: loss 1.455815
# iteration 2000 / 2500: loss 1.560057
# iteration 2100 / 2500: loss 1.461130
# iteration 2200 / 2500: loss 1.505836
# iteration 2300 / 2500: loss 1.394533
# iteration 2400 / 2500: loss 1.466245
# iteration 0 / 2500: loss 2.302588
# iteration 100 / 2500: loss nan
# iteration 200 / 2500: loss nan
# iteration 300 / 2500: loss nan
# iteration 400 / 2500: loss nan
# iteration 500 / 2500: loss nan
# iteration 600 / 2500: loss nan
# iteration 700 / 2500: loss nan
# iteration 800 / 2500: loss nan
# iteration 900 / 2500: loss nan
# iteration 1000 / 2500: loss nan
# iteration 1100 / 2500: loss nan
# iteration 1200 / 2500: loss nan
# iteration 1300 / 2500: loss nan
# iteration 1400 / 2500: loss nan
# iteration 1500 / 2500: loss nan
# iteration 1600 / 2500: loss nan
# iteration 1700 / 2500: loss nan
# iteration 1800 / 2500: loss nan
# iteration 1900 / 2500: loss nan
# iteration 2000 / 2500: loss nan
# iteration 2100 / 2500: loss nan
# iteration 2200 / 2500: loss nan
# iteration 2300 / 2500: loss nan
# iteration 2400 / 2500: loss nan
# iteration 0 / 2500: loss 2.302586
# iteration 100 / 2500: loss 1.516849
# iteration 200 / 2500: loss 1.423751
# iteration 300 / 2500: loss 1.280905
# iteration 400 / 2500: loss 1.309001
# iteration 500 / 2500: loss 1.322723
# iteration 600 / 2500: loss 1.114689
# iteration 700 / 2500: loss 1.338220
# iteration 800 / 2500: loss 1.287418
# iteration 900 / 2500: loss 1.247674
# iteration 1000 / 2500: loss 1.198608
# iteration 1100 / 2500: loss 1.104207
# iteration 1200 / 2500: loss 1.165590
# iteration 1300 / 2500: loss 1.266187
# iteration 1400 / 2500: loss 1.236116
# iteration 1500 / 2500: loss 1.083319
# iteration 1600 / 2500: loss 1.094413
# iteration 1700 / 2500: loss 1.090336
# iteration 1800 / 2500: loss 1.269601
# iteration 1900 / 2500: loss 1.100747
# iteration 2000 / 2500: loss 0.985259
# iteration 2100 / 2500: loss 1.073082
# iteration 2200 / 2500: loss 1.285989
# iteration 2300 / 2500: loss 1.055845
# iteration 2400 / 2500: loss 1.143207
# iteration 0 / 2500: loss 2.302587
# iteration 100 / 2500: loss 1.544071
# iteration 200 / 2500: loss 1.447851
# iteration 300 / 2500: loss 1.543380
# iteration 400 / 2500: loss 1.474627
# iteration 500 / 2500: loss 1.381524
# iteration 600 / 2500: loss 1.390092
# iteration 700 / 2500: loss 1.333156
# iteration 800 / 2500: loss 1.394231
# iteration 900 / 2500: loss 1.470024
# iteration 1000 / 2500: loss 1.307865
# iteration 1100 / 2500: loss 1.336761
# iteration 1200 / 2500: loss 1.339448
# iteration 1300 / 2500: loss 1.197217
# iteration 1400 / 2500: loss 1.350622
# iteration 1500 / 2500: loss 1.348417
# iteration 1600 / 2500: loss 1.410359
# iteration 1700 / 2500: loss 1.270592
# iteration 1800 / 2500: loss 1.173653
# iteration 1900 / 2500: loss 1.377176
# iteration 2000 / 2500: loss 1.271075
# iteration 2100 / 2500: loss 1.392650
# iteration 2200 / 2500: loss 1.383711
# iteration 2300 / 2500: loss 1.263071
# iteration 2400 / 2500: loss 1.241956
# lr 4.192754e-01 reg 7.882190e-03 train accuracy: 0.597041 val accuracy: 0.555000
# lr 5.573614e-01 reg 8.149748e-03 train accuracy: 0.586041 val accuracy: 0.550000
# lr 9.131232e-01 reg 1.933080e-03 train accuracy: 0.704898 val accuracy: 0.596000
# lr 9.401213e-01 reg 4.896757e-03 train accuracy: 0.629163 val accuracy: 0.578000
# lr 1.104537e+00 reg 3.230043e-03 train accuracy: 0.651041 val accuracy: 0.573000
# lr 1.211440e+00 reg 3.397056e-03 train accuracy: 0.649102 val accuracy: 0.581000
# lr 1.502421e+00 reg 3.774695e-03 train accuracy: 0.624980 val accuracy: 0.545000
# lr 1.818189e+00 reg 8.026418e-03 train accuracy: 0.562429 val accuracy: 0.550000
# lr 2.267032e+00 reg 2.639462e-03 train accuracy: 0.634367 val accuracy: 0.558000
# lr 2.272028e+00 reg 3.453154e-03 train accuracy: 0.595469 val accuracy: 0.544000
# lr 2.590800e+00 reg 4.872470e-03 train accuracy: 0.554694 val accuracy: 0.516000
# lr 2.702221e+00 reg 5.785794e-03 train accuracy: 0.544980 val accuracy: 0.516000
# lr 3.318884e+00 reg 4.992323e-03 train accuracy: 0.547714 val accuracy: 0.519000
# lr 3.981750e+00 reg 1.102246e-03 train accuracy: 0.599286 val accuracy: 0.507000
# lr 4.154163e+00 reg 6.747504e-03 train accuracy: 0.100265 val accuracy: 0.087000
# lr 4.155866e+00 reg 3.153422e-03 train accuracy: 0.536878 val accuracy: 0.507000
# lr 4.524325e+00 reg 8.207065e-03 train accuracy: 0.100265 val accuracy: 0.087000
# lr 4.570632e+00 reg 9.687783e-03 train accuracy: 0.100265 val accuracy: 0.087000
# lr 4.649925e+00 reg 6.377241e-03 train accuracy: 0.100265 val accuracy: 0.087000
# lr 4.784786e+00 reg 8.864833e-03 train accuracy: 0.100265 val accuracy: 0.087000
# best validation accuracy achieved during cross-validation: 0.596000

# %%
# Run your neural net classifier on the test set. You should be able to
# get more than 55% accuracy.

test_acc = (net.predict(X_test_feats) == y_test).mean()
print test_acc
# Out:
# 0.556

# %% [markdown]
# # Bonus: Design your own features!
#
# You have seen that simple image features can improve classification performance. So far we have tried HOG and color histograms, but other types of features may be able to achieve even better classification performance.
#
# For bonus points, design and implement a new type of feature and use it for image classification on CIFAR-10. Explain how your feature works and why you expect it to be useful for image classification. Implement it in this notebook, cross-validate any hyperparameters, and compare its performance to the HOG + Color histogram baseline.

# %% [markdown]
# # Bonus: Do something extra!
# Use the material and code we have presented in this assignment to do something interesting. Was there another question we should have asked? Did any cool ideas pop into your head as you were working on the assignment? This is your chance to show off!
